# %%
import pandas as pd

# %%
s1 = pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s2 = pd.Series([10,20,30], index=["Yash","Ashish","Shivel"])
s2
# Out:
# Yash      10
# Ashish    20
# Shivel    30
# dtype: int64

# %%
s2["Yash"]
# Out:
# np.int64(10)

# %%
data = {
    "name" : ["Yoyo" , "Bob" , "Charlie"],
    "age" : [25,45,78],
    "city" : ["delhi", "Mumbai", "Bangalore"]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#       name  age       city
# 0     Yoyo   25      delhi
# 1      Bob   45     Mumbai
# 2  Charlie   78  Bangalore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
